# %% [markdown]
# # SNL 코리아 롱폼 vs 숏폼 YouTube 영상 통계 수집
# YouTube Data API v3로 SNL 코리아 채널의 영상 데이터를 수집해 MySQL DB에 저장합니다.

# %% [markdown]
# ## 0. 환경 설정 및 라이브러리 로드

# %%
# !pip install google-api-python-client
# Out:
# Collecting google-api-python-client
#   Using cached google_api_python_client-2.196.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-python-client) (0.31.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-python-client) (2.49.2)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Using cached google_auth_httplib2-0.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Using cached google_api_core-2.30.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Using cached googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Using cached proto_plus-1.28.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (46.0.3)
# Requirement already satisfied: pyparsing<4,>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2026.1.4)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/anaconda3/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Using cached google_api_python_client-2.196.0-py3-none-any.whl (15.2 MB)
# Using cached google_api_core-2.30.3-py3-none-any.whl (173 kB)
# Using cached google_auth_httplib2-0.4.0-py3-none-any.whl (9.5 kB)
# Using cached googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Using cached proto_plus-1.28.0-py3-none-any.whl (50 kB)
# Using cached uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Installing collected packages: uritemplate, proto-plus, googleapis-common-protos, google-auth-httplib2, google-api-core, google-api-python-client
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [google-api-python-client] [google-api-python-client]
# Successfully installed google-api-core-2.30.3 google-api-python-client-2.196.0 google-auth-httplib2-0.4.0 googleapis-common-protos-1.75.0 proto-plus-1.28.0 uritemplate-4.2.0

# %%
import os
import re
import pandas as pd
from datetime import datetime, timezone
from dotenv import load_dotenv
from googleapiclient.discovery import build
from sqlalchemy import create_engine, text
import pymysql

load_dotenv()

API_KEY      = os.getenv('YOUTUBE_API_KEY')
MYSQL_HOST   = os.getenv('MYSQL_HOST', 'localhost')
MYSQL_USER   = os.getenv('MYSQL_USER', 'root')
MYSQL_PW     = os.getenv('MYSQL_PASSWORD', '')
MYSQL_DB     = os.getenv('MYSQL_DB', 'youtube_data')

assert API_KEY, '.env에 YOUTUBE_API_KEY가 없습니다.'

print(f'API KEY  : {API_KEY[:8]}...')
print(f'MySQL    : {MYSQL_USER}@{MYSQL_HOST}/{MYSQL_DB}')
# Out:
# API KEY  : AIzaSyCu...
# MySQL    : root@localhost/youtube_data

# %% [markdown]
# ## 1. YouTube API 클라이언트 초기화

# %%
def build_youtube_client(api_key: str):
    try:
        client = build('youtube', 'v3', developerKey=api_key)
        print('YouTube API 클라이언트 초기화 완료')
        return client
    except Exception as e:
        print(f'[ERROR] YouTube 클라이언트 초기화 실패: {e}')
        raise

youtube = build_youtube_client(API_KEY)
# Out:
# YouTube API 클라이언트 초기화 완료

# %% [markdown]
# ## 2. MySQL DB 및 엔진 생성

# %%
def create_db_engine(host: str, user: str, pw: str, db: str):
    try:
        # DB가 없으면 먼저 생성
        conn = pymysql.connect(host=host, user=user, password=pw, charset='utf8mb4')
        with conn.cursor() as cur:
            cur.execute(f'CREATE DATABASE IF NOT EXISTS `{db}` CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci')
        conn.close()

        url = f'mysql+pymysql://{user}:{pw}@{host}/{db}?charset=utf8mb4'
        engine = create_engine(url)
        with engine.connect() as c:
            c.execute(text('SELECT 1'))
        print(f'MySQL 연결 성공: {user}@{host}/{db}')
        return engine
    except Exception as e:
        print(f'[ERROR] MySQL 연결 실패: {e}')
        raise

engine = create_db_engine(MYSQL_HOST, MYSQL_USER, MYSQL_PW, MYSQL_DB)
# Out:
# MySQL 연결 성공: root@localhost/youtube_data

# %% [markdown]
# ## 3. SNL 코리아 채널 ID 조회

# %%
def search_channel(client, query: str, max_results: int = 5) -> list[dict]:
    try:
        res = client.search().list(
            q=query,
            type='channel',
            part='snippet',
            maxResults=max_results
        ).execute()
        channels = [
            {
                'channel_id': item['snippet']['channelId'],
                'title':      item['snippet']['title'],
                'desc':       item['snippet']['description'][:60]
            }
            for item in res.get('items', [])
        ]
        return channels
    except Exception as e:
        print(f'[ERROR] 채널 검색 실패: {e}')
        return []

channels = search_channel(youtube, 'SNL 코리아')
for i, ch in enumerate(channels):
    print(f'[{i}] {ch["title"]} | {ch["channel_id"]}')
# Out:
# [0] SNL Korea | UCOTfZwJ4WXANt5yssAYMiJg
# [1] SNL영상모음 | UCCJRtdj-WGWC34OtFURv88w
# [2] SNL 포에버 | UCcg-STmqv9m1b8rbNaMyk6g
# [3] 쿠팡플레이 Coupang Play | UCjn-VbcIkAeXQKCmLJV8YwQ
# [4] SNL 픽 | UC8TC3uiUigR-B_UE9MHHxMA

# %%
CHANNEL_ID = 'UCjn-VbcIkAeXQKCmLJV8YwQ'
print(f'선택된 채널: 쿠팡플레이 ({CHANNEL_ID})')
# Out:
# 선택된 채널: 쿠팡플레이 (UCjn-VbcIkAeXQKCmLJV8YwQ)

# %% [markdown]
# ## 4. 전체 영상 ID 수집

# %%
def get_uploads_playlist_id(client, channel_id: str) -> str:
    try:
        res = client.channels().list(
            id=channel_id,
            part='contentDetails'
        ).execute()
        return res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    except Exception as e:
        print(f'[ERROR] 플레이리스트 ID 조회 실패: {e}')
        raise


def get_all_video_ids(client, playlist_id: str) -> list[str]:
    video_ids = []
    next_page_token = None
    try:
        while True:
            res = client.playlistItems().list(
                playlistId=playlist_id,
                part='contentDetails',
                maxResults=50,
                pageToken=next_page_token
            ).execute()
            for item in res.get('items', []):
                video_ids.append(item['contentDetails']['videoId'])
            next_page_token = res.get('nextPageToken')
            if not next_page_token:
                break
    except Exception as e:
        print(f'[ERROR] 영상 ID 수집 중 오류 (수집된 수: {len(video_ids)}): {e}')
    return video_ids


playlist_id = get_uploads_playlist_id(youtube, CHANNEL_ID)
video_ids   = get_all_video_ids(youtube, playlist_id)
print(f'수집된 영상 수: {len(video_ids)}개')
# Out:
# 수집된 영상 수: 3139개

# %% [markdown]
# ## 5. 영상 상세 정보 수집 및 롱폼/숏폼 분류

# %%
import re

def parse_duration(duration_iso):
    if not duration_iso:
        return 0
    match = re.match(r'PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?', duration_iso)
    if not match:
        return 0
    hours = int(match.group(1) or 0)
    minutes = int(match.group(2) or 0)
    seconds = int(match.group(3) or 0)
    return hours * 3600 + minutes * 60 + seconds

# %%
# def classify_content_type(duration_seconds: int, title: str) -> str:
#     if duration_seconds <= 60 or '#shorts' in title.lower() or '#short' in title.lower():
#         return 'shortform'
#     return 'longform'
def classify_content_type(duration_seconds: int, title: str) -> str:
    """#Shorts 태그 있거나 60초 이하 = 숏폼, 나머지 = 롱폼"""
    if '#shorts' in title.lower() or '#short' in title.lower() or duration_seconds <= 60:
        return 'shortform'
    else:
        return 'longform'

def fetch_video_details(client, ids: list[str]) -> list[dict]:
    records = []
    for i in range(0, len(ids), 50):
        chunk = ids[i:i+50]
        try:
            res = client.videos().list(
                id=','.join(chunk),
                part='snippet,statistics,contentDetails'
            ).execute()
            for item in res.get('items', []):
                snippet = item.get('snippet', {})
                stats   = item.get('statistics', {})
                content = item.get('contentDetails', {})

                duration_iso = content.get('duration', 'PT0S')
                duration_sec = parse_duration(duration_iso)

                title = snippet.get('title', '')
                records.append({
                    'video_id':        item['id'],
                    'title':           title,
                    'published_at':    snippet.get('publishedAt', ''),
                    'duration':        duration_iso,
                    'duration_seconds': duration_sec,
                    'view_count':      stats.get('viewCount'),
                    'like_count':      stats.get('likeCount'),
                    'comment_count':   stats.get('commentCount'),
                    'content_type':    classify_content_type(duration_sec, title),
                    'collected_at':    datetime.now(timezone.utc).isoformat()
                })
        except Exception as e:
            print(f'[ERROR] 영상 상세 수집 실패 (chunk {i}~{i+50}): {e}')
    return records


records = fetch_video_details(youtube, video_ids)
print(f'상세 수집 완료: {len(records)}개')
# Out:
# 상세 수집 완료: 3139개

# %% [markdown]
# ## 6. DataFrame 정리 (타입 변환 + fillna)

# %%
def build_dataframe(records: list[dict]) -> pd.DataFrame:
    df = pd.DataFrame(records)

    num_cols = ['duration_seconds', 'view_count', 'like_count', 'comment_count']
    str_cols = ['video_id', 'title', 'published_at', 'duration', 'content_type', 'collected_at']

    for col in num_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
    for col in str_cols:
        df[col] = df[col].fillna('')

    return df


df = build_dataframe(records)
print(df.dtypes)
print('\n롱폼/숏폼 분포:')
print(df['content_type'].value_counts())
df.head(3)
# Out:
# video_id            object
# title               object
# published_at        object
# duration            object
# duration_seconds     int64
# view_count           int64
# like_count           int64
# comment_count        int64
# content_type        object
# collected_at        object
# dtype: object
#
# 롱폼/숏폼 분포:
# content_type
# longform     1678
# shortform    1461
# Name: count, dtype: int64
#       video_id                                           title  \
# 0  hm1vDZ3MwlU  트렌드세터 머스마 권혁수랑 이정은 배우님 모실게여 🙏ㅣ5월 16일 (토) 저녁 8시
# 1  OjXGGm1qEso                         아궁빵도 주는 빵집이 있다? [봉주르빵집]
# 2  U4NVmrDX-Uw                  위기의 순간 나타난 담임 선생님 😣 [로맨스의 절댓값]
#
#            published_at duration  duration_seconds  view_count  like_count  \
# 0  2026-05-16T02:00:37Z  PT1M20S                80         307          20
# 1  2026-05-15T07:00:16Z    PT28S                28        7612         210
# 2  2026-05-15T04:00:28Z  PT2M33S               153       27502         555
#
#    comment_count content_type                      collected_at
# 0              1     longform  2026-05-16T02:35:47.124309+00:00
# 1             13    shortform  2026-05-16T02:35:47.124362+00:00
# 2             26     longform  2026-05-16T02:35:47.124375+00:00

# %%
def add_engagement_rates(df):
    try:
        df = df.copy()
        df['like_rate'] = df.apply(
            lambda r: round(r['like_count'] / r['view_count'] * 100, 4)
            if r['view_count'] > 0 else 0.0,
            axis=1
        )
        df['comment_rate'] = df.apply(
            lambda r: round(r['comment_count'] / r['view_count'] * 100, 4)
            if r['view_count'] > 0 else 0.0,
            axis=1
        )
        print('like_rate / comment_rate 컬럼 추가 완료')
        print(df[['video_id', 'content_type', 'like_rate', 'comment_rate']].head())
        return df
    except Exception as e:
        print(f'[ERROR] 참여율 컬럼 추가 실패: {e}')
        raise


df = add_engagement_rates(df)
# Out:
# like_rate / comment_rate 컬럼 추가 완료
#       video_id content_type  like_rate  comment_rate
# 0  hm1vDZ3MwlU     longform     6.5147        0.3257
# 1  OjXGGm1qEso    shortform     2.7588        0.1708
# 2  U4NVmrDX-Uw     longform     2.0180        0.0945
# 3  _FnTDX0RE4E     longform     2.9757        0.2645
# 4  iOTcEthpcz0    shortform     1.9033        0.0379

# %% [markdown]
# ## 7. MySQL 저장

# %%
def save_to_mysql(df: pd.DataFrame, engine, table: str = 'snl_videos'):
    try:
        df.to_sql(
            name=table,
            con=engine,
            if_exists='replace',
            index=False,
            chunksize=500
        )
        with engine.connect() as conn:
            count = conn.execute(text(f'SELECT COUNT(*) FROM `{table}`')).scalar()
        print(f'저장 완료: {count}개 레코드 → {MYSQL_DB}.{table}')
    except Exception as e:
        print(f'[ERROR] MySQL 저장 실패: {e}')
        raise


save_to_mysql(df, engine)
# Out:
# 저장 완료: 3139개 레코드 → youtube_data.snl_videos

# %% [markdown]
# ## 8. 저장 결과 확인

# %%
def load_summary(engine, table: str = 'snl_videos') -> pd.DataFrame:
    try:
        summary = pd.read_sql(
            f'''
            SELECT
                content_type,
                COUNT(*)                       AS video_count,
                ROUND(AVG(view_count))         AS avg_views,
                ROUND(AVG(like_count))         AS avg_likes,
                ROUND(AVG(comment_count))      AS avg_comments,
                ROUND(AVG(duration_seconds))   AS avg_duration_sec
            FROM `{table}`
            GROUP BY content_type
            ''',
            con=engine
        )
        return summary
    except Exception as e:
        print(f'[ERROR] 요약 조회 실패: {e}')
        raise


summary = load_summary(engine)
print('=== SNL 코리아 롱폼 vs 숏폼 요약 ===')
display(summary)
# Out:
# === SNL 코리아 롱폼 vs 숏폼 요약 ===
#   content_type  video_count  avg_views  avg_likes  avg_comments  \
# 0     longform         1678   472661.0     3562.0         299.0
# 1    shortform         1461   308733.0     3252.0          66.0
#
#    avg_duration_sec
# 0             236.0
# 1              45.0

# %%
def load_top_videos(engine, n: int = 10, table: str = 'snl_videos') -> pd.DataFrame:
    try:
        return pd.read_sql(
            f'''
            SELECT video_id, title, content_type, view_count, duration_seconds
            FROM `{table}`
            ORDER BY view_count DESC
            LIMIT {n}
            ''',
            con=engine
        )
    except Exception as e:
        print(f'[ERROR] TOP 영상 조회 실패: {e}')
        raise


top10 = load_top_videos(engine)
print('=== 조회수 TOP 10 ===')
display(top10)
# Out:
# === 조회수 TOP 10 ===
#       video_id                                              title  \
# 0  FTTWG-9qSUw          SNL 코리아 | 곽동연 편 | 이수지 애드립에 놀란 곽동연 #shorts
# 1  QxL7_c1RjUU                    직장인들 | 욕해본 적 없는 사람 | 쿠팡플레이 | 쿠팡
# 2  ReKRSTB5PK8  SNL 코리아 시즌2 신혜선 하이라이트 | 열일곱이지만 서른입니다ㅣ SNL 코리아 ...
# 3  ge0G2TozNxg           SNL 코리아 | 육성재 편 | 연애 불변의 원칙 | 쿠팡플레이 | 쿠팡
# 4  HjGF1ga1ijc          SNL 코리아 시즌3 | MZ오피스 전편 특별 편성 | 쿠팡플레이 | 쿠팡
# 5  lhGXTnTaJxs             SNL 코리아 | 안재홍 편 | 스마일 클리닉 | 쿠팡플레이 | 쿠팡
# 6  MpPoiAhoz2c  1분 쿠플 | 비상선언 | 소시오패스가 비행기 티켓을 끊을 때 | 쿠팡플레이 | 쿠...
# 7  PBTjJLrjKcA  SNL 코리아 인턴 기자 첫 번째 하이라이트 | Weekend Update 위켄드 ...
# 8  Lfq9O0z-G9k  SNL 코리아 시즌3 | 채수빈 편 하이라이트 | 너와 나의 결혼수업 | 쿠팡플레이...
# 9  pAV1l9qUtwo  SNL 코리아 시즌5 | 이유미 편 | 대꽃밭 연기 1티어 | 쿠팡플레이 코미디 쇼...
#
#   content_type  view_count  duration_seconds
# 0    shortform    17012981                59
# 1    shortform    14944647                29
# 2     longform    11047089               223
# 3     longform    10616672                66
# 4     longform    10087990               752
# 5     longform     9398238                74
# 6    shortform     8620126                58
# 7     longform     8295134               179
# 8     longform     7970595               293
# 9    shortform     7629833                60

# %% [markdown]
# ## 9. 콘텐츠 유형별 통계 시각화

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go


def plot_content_type_stats(summary: pd.DataFrame):
    try:
        order = ['shortform', 'longform']
        label_map = {'shortform': '숏폼', 'longform': '롱폼'}
        colors    = {'shortform': '#636EFA', 'longform': '#00CC96'}

        df_plot = (
            summary
            .set_index('content_type')
            .reindex(order)
            .reset_index()
        )
        df_plot['label'] = df_plot['content_type'].map(label_map)
        bar_colors = [colors[ct] for ct in df_plot['content_type']]

        metrics = [
            ('avg_views',    '평균 조회수'),
            ('avg_likes',    '평균 좋아요수'),
            ('avg_comments', '평균 댓글수'),
        ]

        fig = make_subplots(
            rows=1, cols=3,
            subplot_titles=[m[1] for m in metrics],
            horizontal_spacing=0.1
        )

        for col_pos, (col_name, metric_label) in enumerate(metrics, start=1):
            fig.add_trace(
                go.Bar(
                    x=df_plot['label'],
                    y=df_plot[col_name],
                    marker_color=bar_colors,
                    text=df_plot[col_name].apply(lambda v: f'{v:,.0f}'),
                    textposition='outside',
                    showlegend=False,
                ),
                row=1, col=col_pos
            )

        fig.update_layout(
            title_text='SNL 코리아 — 콘텐츠 유형별 평균 지표',
            title_x=0.5,
            title_font_size=16,
            height=480,
            template='plotly_white',
            margin=dict(t=100, b=60)
        )
        fig.update_yaxes(tickformat=',')
        fig.show()

    except Exception as e:
        print(f'[ERROR] 시각화 실패: {e}')
        raise


plot_content_type_stats(summary)

# %% [markdown]
# ## 10. 콘텐츠 유형별 평균 참여율 시각화

# %%
df['like_rate'] = df['like_count'] / df['view_count'].replace(0, 1) * 100
df['comment_rate'] = df['comment_count'] / df['view_count'].replace(0, 1) * 100

df
# Out:
#          video_id                                              title  \
# 0     hm1vDZ3MwlU     트렌드세터 머스마 권혁수랑 이정은 배우님 모실게여 🙏ㅣ5월 16일 (토) 저녁 8시
# 1     OjXGGm1qEso                            아궁빵도 주는 빵집이 있다? [봉주르빵집]
# 2     U4NVmrDX-Uw                     위기의 순간 나타난 담임 선생님 😣 [로맨스의 절댓값]
# 3     _FnTDX0RE4E                            우린 친구였어 💘 1탄 [로맨스의 절댓값]
# 4     iOTcEthpcz0                           공감되는 학교 생활ㅋㅋㅋ [로맨스의 절댓값]
# ...           ...                                                ...
# 3134  qjWrwDxQgBA  ⭐️쿠팡플레이 단독 공개⭐️ 연애 상담 하고 싶다면 봐야하는 드라마, 러브 라이프 ...
# 3135  utxptsZ6bjI  ⭐️쿠팡플레이 단독 공개⭐️ 연애가 고민이라면 봐야하는 드라마, 러브 라이프 | 러...
# 3136  WF4KrZZ_Vmk          귀신 들린 집만 취급하는 부동산 이야기 | 대박부동산 X 쿠팡플레이 예고편
# 3137  c3QPv1wUv9k              부동산에서 퇴마를 하게 된 이유 | 대박부동산 X 쿠팡플레이 예고편
# 3138  d9n6YQ-Jtl4        귀신 들린 집 매매 전문 부동산이 있다고? | 대박부동산 X 쿠팡플레이 예고편
#
#               published_at duration  duration_seconds  view_count  like_count  \
# 0     2026-05-16T02:00:37Z  PT1M20S                80         307          20
# 1     2026-05-15T07:00:16Z    PT28S                28        7612         210
# 2     2026-05-15T04:00:28Z  PT2M33S               153       27502         555
# 3     2026-05-14T12:00:53Z  PT6M54S               414        6049         180
# 4     2026-05-14T11:01:10Z    PT53S                53       15815         301
# ...                    ...      ...               ...         ...         ...
# 3134  2021-04-14T09:00:31Z  PT1M46S               106        3901          13
# 3135  2021-04-13T09:52:21Z    PT31S                31        6223          27
# 3136  2021-04-07T11:00:11Z    PT42S                42        6375          37
# 3137  2021-04-07T09:00:27Z    PT35S                35        3311          33
# 3138  2021-04-07T03:00:15Z    PT20S                20        7939          34
#
#       comment_count content_type                      collected_at  like_rate  \
# 0                 1     longform  2026-05-16T02:35:47.124309+00:00   6.514658
# 1                13    shortform  2026-05-16T02:35:47.124362+00:00   2.758802
# 2                26     longform  2026-05-16T02:35:47.124375+00:00   2.018035
# 3                16     longform  2026-05-16T02:35:47.124385+00:00   2.975698
# 4                 6    shortform  2026-05-16T02:35:47.124394+00:00   1.903256
# ...             ...          ...                               ...        ...
# 3134              1     longform  2026-05-16T02:36:02.529025+00:00   0.333248
# 3135              3    shortform  2026-05-16T02:36:02.529034+00:00   0.433874
# 3136              2    shortform  2026-05-16T02:36:02.529043+00:00   0.580392
# 3137              1    shortform  2026-05-16T02:36:02.529052+00:00   0.996678
# 3138              4    shortform  2026-05-16T02:36:02.529060+00:00   0.428266
#
#       comment_rate
# 0         0.325733
# 1         0.170783
# 2         0.094539
# 3         0.264507
# 4         0.037939
# ...            ...
# 3134      0.025634
# 3135      0.048208
# 3136      0.031373
# 3137      0.030202
# 3138      0.050384
#
# [3139 rows x 12 columns]

# %%
import plotly.graph_objects as go


def plot_engagement_rates(df):
    try:
        order     = ['shortform', 'longform']
        label_map = {'shortform': '숏폼', 'longform': '롱폼'}

        eng = (
            df.groupby('content_type')[['like_rate', 'comment_rate']]
            .mean()
            .reindex(order)
            .reset_index()
        )
        eng['label'] = eng['content_type'].map(label_map)

        fig = go.Figure()

        fig.add_trace(go.Bar(
            name='평균 좋아요율',
            x=eng['label'],
            y=eng['like_rate'].round(4),
            marker_color='#636EFA',
            text=eng['like_rate'].apply(lambda v: f'{v:.4f}%'),
            textposition='outside'
        ))

        fig.add_trace(go.Bar(
            name='평균 댓글율',
            x=eng['label'],
            y=eng['comment_rate'].round(4),
            marker_color='#EF553B',
            text=eng['comment_rate'].apply(lambda v: f'{v:.4f}%'),
            textposition='outside'
        ))

        fig.update_layout(
            title_text='SNL 코리아 — 콘텐츠 유형별 평균 참여율',
            title_x=0.5,
            title_font_size=16,
            barmode='group',
            yaxis_title='참여율 (%)',
            height=480,
            template='plotly_white',
            legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='right', x=1)
        )
        fig.update_yaxes(tickformat='.4f', ticksuffix='%')
        fig.show()

    except Exception as e:
        print(f'[ERROR] 참여율 시각화 실패: {e}')
        raise


plot_engagement_rates(df)
