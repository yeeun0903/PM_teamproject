# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import re

options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("--disable-blink-features=AutomationControlled")

driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()),
    options=options
)

BASE_URL = "https://www.vigloo.com/ko?tab=categories"


def scroll_once(pause=1.0):
    try:
        container = driver.find_element(By.ID, "desktop-scroll-container")
        driver.execute_script(
            "arguments[0].scrollTop = arguments[0].scrollHeight;",
            container
        )
    except:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    time.sleep(pause)


def load_cards_until(target_idx, max_scrolls=6, pause=0.8):
    for _ in range(max_scrolls):
        cards = driver.find_elements(By.CSS_SELECTOR, "div.vds-bundle-card")

        if len(cards) > target_idx:
            return cards

        scroll_once(pause)

    return driver.find_elements(By.CSS_SELECTOR, "div.vds-bundle-card")


def get_card_info(card):
    title = ""
    tags = ""

    h3 = card.find_elements(By.CSS_SELECTOR, "h3")
    if h3:
        title = h3[0].text.strip()

    p = card.find_elements(By.CSS_SELECTOR, "p")
    if p:
        tags = p[0].text.strip()

    return title, tags


def get_total_episode(body_text):
    ranges = re.findall(r"\d+\s*-\s*\d+(?:\(완결\))?", body_text)

    if ranges:
        nums = re.findall(r"\d+", " ".join(ranges))
        return max(map(int, nums))

    nums = re.findall(r"\n(\d{1,3})\n", body_text)
    if nums:
        return max(map(int, nums))

    return ""


def get_synopsis_from_detail():
    ps = driver.find_elements(By.CSS_SELECTOR, "p.text-gray-white")
    candidates = []

    for p in ps:
        txt = p.text.strip()

        if (
            len(txt) >= 30
            and "멤버십 구독" not in txt
            and "무제한 시청하기" not in txt
            and "비슷한 콘텐츠" not in txt
            and "에피소드" not in txt
            and "주소:" not in txt
            and "VIGLOO" not in txt
        ):
            candidates.append(txt)

    return max(candidates, key=len) if candidates else ""


def get_genre_from_detail():
    spans = driver.find_elements(By.CSS_SELECTOR, "span.text-gray-400")
    genre_list = []

    for span in spans:
        txt = span.text.strip()

        if txt and len(txt) <= 10 and txt not in genre_list:
            genre_list.append(txt)

    return " · ".join(genre_list)


def get_country_from_detail():
    countries = ["한국", "미국", "일본", "중국", "태국", "기타"]

    spans = driver.find_elements(By.CSS_SELECTOR, "span.text-gray-400")

    for span in spans:
        txt = span.text.strip()

        if txt in countries:
            return txt

    return ""


print("=" * 50)
print("STEP 1 : 카드 목록 수집")
print("=" * 50)

driver.get(BASE_URL)
time.sleep(3)

for i in range(4):
    scroll_once(1.2)
    cards = driver.find_elements(By.CSS_SELECTOR, "div.vds-bundle-card")
    print(f"스크롤 {i + 1}회 | 카드 수: {len(cards)}")

cards = driver.find_elements(By.CSS_SELECTOR, "div.vds-bundle-card")
total_cards = len(cards)

item_list = []

for idx, card in enumerate(cards):
    title, tags = get_card_info(card)

    item_list.append({
        "순번": idx + 1,
        "제목": title,
        "태그/설명": tags
    })

print(f"\n최종 카드 수: {len(item_list)}")

results = []

print("\n" + "=" * 50)
print("STEP 2 : 상세 정보 수집")
print("=" * 50)

for item in item_list:
    idx = item["순번"] - 1
    title = item["제목"]
    tags = item["태그/설명"]

    print(f"[{item['순번']}/{len(item_list)}] {title}", end=" ... ")

    try:
        driver.get(BASE_URL)
        time.sleep(1.5)

        cards = load_cards_until(idx, max_scrolls=6, pause=0.8)

        if len(cards) <= idx:
            print("카드 없음")

            results.append({
                "순번": item["순번"],
                "제목": title,
                "태그/설명": tags,
                "국가": "",
                "장르": "",
                "줄거리": "",
                "총회차": "",
                "URL": ""
            })
            continue

        card = cards[idx]

        try:
            click_target = card.find_element(By.CSS_SELECTOR, "div.vds-relative")
        except:
            click_target = card

        driver.execute_script(
            "arguments[0].scrollIntoView({block:'center'});",
            click_target
        )
        time.sleep(0.3)

        driver.execute_script("arguments[0].click();", click_target)
        time.sleep(2)

        detail_url = driver.current_url

        if "/video/" not in detail_url:
            print("이동 실패")

            results.append({
                "순번": item["순번"],
                "제목": title,
                "태그/설명": tags,
                "국가": "",
                "장르": "",
                "줄거리": "",
                "총회차": "",
                "URL": detail_url
            })
            continue

        body_text = driver.find_element(By.TAG_NAME, "body").text

        country = get_country_from_detail()
        genre = get_genre_from_detail()
        synopsis = get_synopsis_from_detail()
        total_episode = get_total_episode(body_text)

        results.append({
            "순번": item["순번"],
            "제목": title,
            "태그/설명": tags,
            "국가": country,
            "장르": genre,
            "줄거리": synopsis,
            "총회차": total_episode,
            "URL": detail_url
        })

        print(detail_url)

    except Exception as e:
        print(f"오류: {e}")

        results.append({
            "순번": item["순번"],
            "제목": title,
            "태그/설명": tags,
            "국가": "",
            "장르": "",
            "줄거리": "",
            "총회차": "",
            "URL": ""
        })

    if len(results) % 20 == 0:
        temp_df = pd.DataFrame(results)
        temp_df.to_csv("vigloo_temp.csv", index=False, encoding="utf-8-sig")


df = pd.DataFrame(results)

df.to_csv("vigloo_all_works.csv", index=False, encoding="utf-8-sig")
df.to_excel("vigloo_all_works.xlsx", index=False)

print("\n" + "=" * 50)
print("수집 완료")
print(f"총 저장 작품 수: {len(df)}개")
print("저장 파일: vigloo_all_works.csv / vigloo_all_works.xlsx")
print("=" * 50)

print(df.head())

driver.quit()
# Out:
# ==================================================
# STEP 1 : 카드 목록 수집
# ==================================================
# 스크롤 1회 | 카드 수: 90
# 스크롤 2회 | 카드 수: 150
# 스크롤 3회 | 카드 수: 197
# 스크롤 4회 | 카드 수: 197
#
# 최종 카드 수: 197
#
# ==================================================
# STEP 2 : 상세 정보 수집
# ==================================================
# [1/197] 천재 아기의 인생 역전 ... https://www.vigloo.com/ko/video/15001849?episode=1
# [2/197] 수상한 남편의 이중생활 ... https://www.vigloo.com/ko/video/15001753?episode=1
# [3/197] 닿을 수 있는 그녀 ... https://www.vigloo.com/ko/video/15001453?episode=1
# [4/197] 모쏠지옥 ... https://www.vigloo.com/ko/video/15001786?episode=1
# [5/197] 비서할래 와이프할래? ... https://www.vigloo.com/ko/video/15001355?episode=1
# [6/197] 뚱보 아내는 조폭 마누라 ... https://www.vigloo.com/ko/video/15001651?episode=1
# [7/197] 국가권력급 상속자가 돌아왔다 ... https://www.vigloo.com/ko/video/15001189?episode=1
# [8/197] 타임리프 로맨스: 은밀한 복수 ... https://www.vigloo.com/ko/video/15000140?episode=1
# [9/197] 오늘 한류스타와 이혼하겠습니다 ... https://www.vigloo.com/ko/video/15000826?episode=1
# [10/197] 장녀 결혼 일기 ... https://www.vigloo.com/ko/video/15000728?episode=1
# [11/197] 그 여자를 유혹해줘 ... https://www.vigloo.com/ko/video/15001717?episode=1
# [12/197] D-100 : 남편을 리셋합니다 ... https://www.vigloo.com/ko/video/15001590?episode=1
# [13/197] 해야만 하는 쉐어하우스2 ... https://www.vigloo.com/ko/video/15000350?episode=1
# [14/197] 해야만 하는 쉐어하우스 in Japan ... https://www.vigloo.com/ko/video/15001420?episode=1
# [15/197] 사내에서는 정숙할 것 ... https://www.vigloo.com/ko/video/15001057?episode=1
# [16/197] 선배님, 모두 우연인가요 ... https://www.vigloo.com/ko/video/15000696?episode=1
# [17/197] 엄마가 나를 팔았다 ... https://www.vigloo.com/ko/video/15001817?episode=1
# [18/197] 낮져밤이 오피스 ... https://www.vigloo.com/ko/video/15001522?episode=1
# [19/197] 이 섬에서만 할 수 있어 ... https://www.vigloo.com/ko/video/15001822?episode=1
# [20/197] 로맨틱 아일랜드 ... https://www.vigloo.com/ko/video/15000468?episode=1
# [21/197] 커피가 친절하고 사장님이 맛있어요 ... https://www.vigloo.com/ko/video/15000324?episode=1
# [22/197] 완벽한 사모님, CEO를 울리다 ... https://www.vigloo.com/ko/video/15001486?episode=1
# [23/197] 흙수저 싱글맘의 기적 ... https://www.vigloo.com/ko/video/15000694?episode=1
# [24/197] 내 남편의 여자들 ... https://www.vigloo.com/ko/video/15001785?episode=1
# [25/197] 당신은 나의 신부 ... https://www.vigloo.com/ko/video/15001652?episode=1
# [26/197] 전남친의 대표님과 결혼했습니다 ... https://www.vigloo.com/ko/video/15001025?episode=1
# [27/197] 시혼궁녀 ... https://www.vigloo.com/ko/video/15001421?episode=1
# [28/197] 불장난 ... https://www.vigloo.com/ko/video/15001488?episode=1
# [29/197] 비서와 사랑에 빠질 확률 ... https://www.vigloo.com/ko/video/15001784?episode=1
# [30/197] 경성 여우 스캔들 ... https://www.vigloo.com/ko/video/15001222?episode=1
# [31/197] 로펌 에이스 변호사와 비서 ... https://www.vigloo.com/ko/video/15000344?episode=1
# [32/197] 돌아와 내 딸 천지영 ... https://www.vigloo.com/ko/video/15001123?episode=1
# [33/197] 고등학생 보스에 베팅했습니다 ... https://www.vigloo.com/ko/video/15001161?episode=1
# [34/197] 남장비서 ... https://www.vigloo.com/ko/video/15000397?episode=1
# [35/197] 우리 지금 무슨 사이 ... https://www.vigloo.com/ko/video/15000277?episode=1
# [36/197] 꿈에서 자유로 ... https://www.vigloo.com/ko/video/15001684?episode=1
# [37/197] 심장이 기억하는 사랑 ... https://www.vigloo.com/ko/video/15001555?episode=1
# [38/197] 남편을 유혹해줘요 ... https://www.vigloo.com/ko/video/15001685?episode=1
# [39/197] 러브 스트라이크 ... https://www.vigloo.com/ko/video/15000279?episode=1
# [40/197] 벙어리 아내를 구한 신선 ... https://www.vigloo.com/ko/video/15001455?episode=1
# [41/197] 뽀삐가 재벌남으로 돌아왔다 ... https://www.vigloo.com/ko/video/15001884?episode=1
# [42/197] 폭군의 약혼녀가 되겠습니다 ... https://www.vigloo.com/ko/video/15000760?episode=1
# [43/197] 아들의 주치의와 두 번째 사랑 ... https://www.vigloo.com/ko/video/15000399?episode=1
# [44/197] 멍청한 쓰레기 남편은 즉시 폐기! ... https://www.vigloo.com/ko/video/15001552?episode=1
# [45/197] 의치한 스캔들 ... https://www.vigloo.com/ko/video/15001589?episode=1
# [46/197] 가시나무를 파헤쳐 너의 곁으로 ... https://www.vigloo.com/ko/video/15000895?episode=1
# [47/197] 절친 아빠를 탐하다 ... https://www.vigloo.com/ko/video/15001718?episode=1
# [48/197] 서울원나잇 ... https://www.vigloo.com/ko/video/15000296?episode=1
# [49/197] 악녀로 빙의중! ... https://www.vigloo.com/ko/video/15000176?episode=1
# [50/197] 김대표의 엽기적인 부인 ... https://www.vigloo.com/ko/video/15000565?episode=1
# [51/197] 소꿉친구 대표님과 계약 결혼 ... https://www.vigloo.com/ko/video/15000264?episode=1
# [52/197] 연: 그날 밤, 종이 되다 ... https://www.vigloo.com/ko/video/15000342?episode=1
# [53/197] 이 키스, 연구 목적입니다! ... https://www.vigloo.com/ko/video/15000793?episode=1
# [54/197] 내 남자친구는 600살 ... https://www.vigloo.com/ko/video/15001024?episode=1
# [55/197] 이 사랑 치료 되나요? ... https://www.vigloo.com/ko/video/15000958?episode=1
# [56/197] 마지막 베팅 ~금단의 사랑에 빠지다~ ... https://www.vigloo.com/ko/video/15001754?episode=1
# [57/197] 블러드체인 ... https://www.vigloo.com/ko/video/15000286?episode=1
# [58/197] 내 파트너는 악마 ... https://www.vigloo.com/ko/video/15000293?episode=1
# [59/197] 메소드 ... https://www.vigloo.com/ko/video/15000925?episode=1
# [60/197] X를 사수하라 ... https://www.vigloo.com/ko/video/15001134?episode=1
# [61/197] Dr.K ... https://www.vigloo.com/ko/video/15001750?episode=1
# [62/197] 남사친이 재벌이었다 ... https://www.vigloo.com/ko/video/15000299?episode=1
# [63/197] 플래티넘 - 그들이 사는 세상 ... https://www.vigloo.com/ko/video/15000305?episode=1
# [64/197] 헤이트 메리지 ... https://www.vigloo.com/ko/video/15000564?episode=1
# [65/197] 이혼하고 나랑 놀래? ... https://www.vigloo.com/ko/video/15000172?episode=1
# [66/197] 레드몬스터: 악마를 향한 복수 ... https://www.vigloo.com/ko/video/15000330?episode=1
# [67/197] 아무짝에 쓸모없는 사랑 ... https://www.vigloo.com/ko/video/15000794?episode=1
# [68/197] 사이비 교주의 아내가 되었습니다 ... https://www.vigloo.com/ko/video/15000322?episode=1
# [69/197] 게스트하우스의 맛 ... https://www.vigloo.com/ko/video/15000142?episode=1
# [70/197] 죽여야 하는, 로맨스 ... https://www.vigloo.com/ko/video/15000532?episode=1
# [71/197] 도련님은 전남친 ... https://www.vigloo.com/ko/video/15001092?episode=1
# [72/197] 아빠의 절친과의 뜨거운 밤 ... https://www.vigloo.com/ko/video/15000497?episode=1
# [73/197] 블러드 메이트 ... https://www.vigloo.com/ko/video/15000232?episode=1
# [74/197] 잔혹한 나의 악마 ... https://www.vigloo.com/ko/video/15000205?episode=1
# [75/197] 어느 날 예뻐지고 마침내 로맨스 당했다 ... https://www.vigloo.com/ko/video/15000596?episode=1
# [76/197] 청담국제고등학교 - 미술반 ... https://www.vigloo.com/ko/video/15000244?episode=1
# [77/197] 죽이고 싶은 X들 : 간통수사대 ... https://www.vigloo.com/ko/video/15000161?episode=1
# [78/197] 상간녀에게 빙의 되었습니다 ... https://www.vigloo.com/ko/video/15000311?episode=1
# [79/197] 엘러베이터 S1 ... https://www.vigloo.com/ko/video/15001422?episode=1
# [80/197] 세상에서 가장 아픈 키스 ... https://www.vigloo.com/ko/video/15000292?episode=1
# [81/197] 손을 잃은 명의 ... https://www.vigloo.com/ko/video/15000862?episode=1
# [82/197] 러닝메이트 ... https://www.vigloo.com/ko/video/15001094?episode=1
# [83/197] 이 소설에서 나가는 방법 ... https://www.vigloo.com/ko/video/15000628?episode=1
# [84/197] 지옥에서 찾아온 나의 구원자 ... https://www.vigloo.com/ko/video/15000431?episode=1
# [85/197] 사랑은 계약 후에 ... https://www.vigloo.com/ko/video/15000208?episode=1
# [86/197] 마이 리틀 셰프 ... https://www.vigloo.com/ko/video/15001919?episode=1
# [87/197] 내 남편이 나를 죽였다 ... https://www.vigloo.com/ko/video/15000314?episode=1
# [88/197] 아이돌, 남침! ... https://www.vigloo.com/ko/video/15000861?episode=1
# [89/197] 그의 마음은 날 향하지 않았다 ... https://www.vigloo.com/ko/video/15000863?episode=1
# [90/197] 질풍같은 프로포즈 ... https://www.vigloo.com/ko/video/15000892?episode=1
# [91/197] 최애의 사수가 되었다 ... https://www.vigloo.com/ko/video/15000154?episode=1
# [92/197] 야쿠자 딸의 악덕 기업 응징 프로젝트 ... https://www.vigloo.com/ko/video/15001159?episode=1
# [93/197] 싱글맘의 행운 ... https://www.vigloo.com/ko/video/15001356?episode=1
# [94/197] 미안하지만, 내 애인은 네 아빠야 ... https://www.vigloo.com/ko/video/15001026?episode=1
# [95/197] 여왕벌맘 위에, 히든 재벌맘 ... https://www.vigloo.com/ko/video/15001387?episode=1
# [96/197] 수진과 수진: 내 남편을 뺏어봐 ... https://www.vigloo.com/ko/video/15000433?episode=1
# [97/197] 내 남편을 유혹해줘 ... https://www.vigloo.com/ko/video/15000148?episode=1
# [98/197] 아이돌의 이중생활 ... https://www.vigloo.com/ko/video/15000252?episode=1
# [99/197] 설레면 지는 거다 ... https://www.vigloo.com/ko/video/15000162?episode=1
# [100/197] 누가 독한X인지 궁금해졌어 ... https://www.vigloo.com/ko/video/15000894?episode=1
# [101/197] 내 소울메이트는 유부남 교수님 ... 카드 없음
# [102/197] 20살 딸이 생겼습니다 ... https://www.vigloo.com/ko/video/15000149?episode=1
# [103/197] 디어엑스 ... https://www.vigloo.com/ko/video/15001093?episode=1
# [104/197] 운명을 도둑맞은 진짜 딸 ... https://www.vigloo.com/ko/video/15000312?episode=1
# [105/197] 엘러베이터 S2 ... https://www.vigloo.com/ko/video/15001487?episode=1
# [106/197] 싱글맘에게 찾아온, 인생 최고의 사랑 ... https://www.vigloo.com/ko/video/15000960?episode=1
# [107/197] 낮잠공주의 스포일러 ... https://www.vigloo.com/ko/video/15000278?episode=1
# [108/197] 밸런스게임을 시작하시겠습니까? ... https://www.vigloo.com/ko/video/15000239?episode=1
# [109/197] 화끈한 요리 ... https://www.vigloo.com/ko/video/15000859?episode=1
# [110/197] 붉은 그림자 ... https://www.vigloo.com/ko/video/15001289?episode=1
# [111/197] 알바생 아빠의 정체는 재벌? ... https://www.vigloo.com/ko/video/15000334?episode=1
# [112/197] 블러드체인 (Clean Ver.) ... https://www.vigloo.com/ko/video/15000303?episode=1
# [113/197] 억만장자 전처의 역습 ... https://www.vigloo.com/ko/video/15001190?episode=1
# [114/197] 블러드바운드 루나 ... https://www.vigloo.com/ko/video/15001324?episode=1
# [115/197] 며느리는 귀싸대기 회장님 ... https://www.vigloo.com/ko/video/15000282?episode=1
# [116/197] 러브 매직 홍시 Bar ... https://www.vigloo.com/ko/video/15000496?episode=1
# [117/197] 서울: 2053 ... https://www.vigloo.com/ko/video/15000430?episode=1
# [118/197] 타임 리프 조선 ... https://www.vigloo.com/ko/video/15000595?episode=1
# [119/197] 너의 영혼을 갈아줄게 ... https://www.vigloo.com/ko/video/15000464?episode=1
# [120/197] 동거학개론 ... https://www.vigloo.com/ko/video/15000533?episode=1
# [121/197] 언니의 약혼자와 사랑에 빠졌습니다 ... https://www.vigloo.com/ko/video/15000201?episode=1
# [122/197] 계약 아내, 정비공과 사랑에 빠지다 ... https://www.vigloo.com/ko/video/15000315?episode=1
# [123/197] 내 남자의 스마트폰 ... https://www.vigloo.com/ko/video/15001090?episode=1
# [124/197] 회귀한 상속녀는 참지 않아 ... https://www.vigloo.com/ko/video/15000466?episode=1
# [125/197] 백만장자와 오피스 스캔들 ... https://www.vigloo.com/ko/video/15000159?episode=1
# [126/197] 쿼터백의 팀 닥터 ... https://www.vigloo.com/ko/video/15000529?episode=1
# [127/197] XXL 디바 퀸의 복수 ... https://www.vigloo.com/ko/video/15000893?episode=1
# [128/197] 메타 러브 ... https://www.vigloo.com/ko/video/15000463?episode=1
# [129/197] 착한 교수의 위험한 사랑 ... https://www.vigloo.com/ko/video/15000343?episode=1
# [130/197] 선 넘은 사랑: 나의 적과 가짜 연애 ... https://www.vigloo.com/ko/video/15000927?episode=1
# [131/197] 비밀스러운 과거를 가진 신부 ... https://www.vigloo.com/ko/video/15000991?episode=1
# [132/197] 풀빌라에서 생긴 일 ... https://www.vigloo.com/ko/video/15000136?episode=1
# [133/197] 프린세스 메이커 ... https://www.vigloo.com/ko/video/15000141?episode=1
# [134/197] CEO 남장비서의 이중생활 ... https://www.vigloo.com/ko/video/15000245?episode=1
# [135/197] 슈퍼카 신데렐라 스토리 ... https://www.vigloo.com/ko/video/15000295?episode=1
# [136/197] 그 여름, 교수님과의 비밀 ... https://www.vigloo.com/ko/video/15000302?episode=1
# [137/197] 마피아 보스의 눈먼 신부 ... https://www.vigloo.com/ko/video/15000469?episode=1
# [138/197] 복서의 순정 ... https://www.vigloo.com/ko/video/15000227?episode=1
# [139/197] 대통령님, 저를 찾아주세요! ... https://www.vigloo.com/ko/video/15000730?episode=1
# [140/197] 라이벌 알파와의 사랑 ... https://www.vigloo.com/ko/video/15000323?episode=1
# [141/197] 그 여름 비치하우스에서 ... https://www.vigloo.com/ko/video/15000467?episode=1
# [142/197] 이창호의 상상은 현실이 된다 ... https://www.vigloo.com/ko/video/15000325?episode=1
# [143/197] 강아지 집사와 플레이보이의 계약 결혼 ... https://www.vigloo.com/ko/video/15000316?episode=1
# [144/197] 내 첫사랑이 우리 가문의 라이벌?! ... https://www.vigloo.com/ko/video/15000432?episode=1
# [145/197] 미친 엄마의 복수극 ... https://www.vigloo.com/ko/video/15000301?episode=1
# [146/197] 카우보이 도련님의 숨겨진 신부 ... https://www.vigloo.com/ko/video/15000174?episode=1
# [147/197] 내 전남친은 파일럿 ... https://www.vigloo.com/ko/video/15000398?episode=1
# [148/197] 저주받은 표식의 공주 ... https://www.vigloo.com/ko/video/15000318?episode=1
# [149/197] 거짓말로 재벌가의 며느리가 되었습니다 ... https://www.vigloo.com/ko/video/15000257?episode=1
# [150/197] 우편실의 억만장자 ... https://www.vigloo.com/ko/video/15000307?episode=1
# [151/197] 버림받은 상속녀의 복수극 ... https://www.vigloo.com/ko/video/15000729?episode=1
# [152/197] 시뮬레이션 게임 속 사무라이와 운명적 만남 ... https://www.vigloo.com/ko/video/15000265?episode=1
# [153/197] 88년생 베스트프렌드 ... https://www.vigloo.com/ko/video/15000160?episode=1
# [154/197] 늑대의 신부가 된 뱀파이어 ... https://www.vigloo.com/ko/video/15000319?episode=1
# [155/197] 장군의 딸을 사랑한 이등병은 숨겨진 재벌 ... https://www.vigloo.com/ko/video/15000327?episode=1
# [156/197] 웨딩 플래너의 사랑 ... https://www.vigloo.com/ko/video/15000234?episode=1
# [157/197] 귀살 ... https://www.vigloo.com/ko/video/15000207?episode=1
# [158/197] 에이미 벤슨의 비밀 ... https://www.vigloo.com/ko/video/15000351?episode=1
# [159/197] 재투성이 공주★야요이 ... https://www.vigloo.com/ko/video/15000240?episode=1
# [160/197] 울끈불끈 사장의 심장을 훔친 슈가펄레이디 ... https://www.vigloo.com/ko/video/15000291?episode=1
# [161/197] 남친 찾기 프로젝트 -5명과의 키스- ... https://www.vigloo.com/ko/video/15000727?episode=1
# [162/197] 카지노 왕자에게 딱 찍히다 ... https://www.vigloo.com/ko/video/15000500?episode=1
# [163/197] 연하남의 알리바이 ... https://www.vigloo.com/ko/video/15000289?episode=1
# [164/197] 도플갱어와 랜덤채팅 ... https://www.vigloo.com/ko/video/15000143?episode=1
# [165/197] 나의 슈퍼스타와 연애하기 ... https://www.vigloo.com/ko/video/15000276?episode=1
# [166/197] 내가 사랑에 빠진 그 여름 캠프 ... https://www.vigloo.com/ko/video/15000400?episode=1
# [167/197] 비밀 연애 컨설턴트 ... https://www.vigloo.com/ko/video/15000288?episode=1
# [168/197] 사랑의 고통에 빠져버렸다! ... https://www.vigloo.com/ko/video/15000155?episode=1
# [169/197] 미녀는 괴로워 ~런웨이에서 복수를~ ... https://www.vigloo.com/ko/video/15000349?episode=1
# [170/197] 캠퍼스의 연인들 ... https://www.vigloo.com/ko/video/15000308?episode=1
# [171/197] 신입 인턴은 CEO? ... https://www.vigloo.com/ko/video/15000283?episode=1
# [172/197] 연애의 법칙 ... https://www.vigloo.com/ko/video/15000298?episode=1
# [173/197] 가출한 왕자의 비밀스러운 휴가 ... https://www.vigloo.com/ko/video/15000562?episode=1
# [174/197] 복수의 소나타 ... https://www.vigloo.com/ko/video/15000137?episode=1
# [175/197] 남의 남자 ... https://www.vigloo.com/ko/video/15000274?episode=1
# [176/197] 비밀의 밤, 사라진 너 ... https://www.vigloo.com/ko/video/15000250?episode=1
# [177/197] 불 속에서 만난 상속자 ... https://www.vigloo.com/ko/video/15000304?episode=1
# [178/197] 내 상사와의 요트 위 로맨스 ... https://www.vigloo.com/ko/video/15000345?episode=1
# [179/197] 잃어버린 아내 ... https://www.vigloo.com/ko/video/15000259?episode=1
# [180/197] 뱀파이어의 입맞춤: 피로 맺은 사랑 ... https://www.vigloo.com/ko/video/15000249?episode=1
# [181/197] 마피아 보디가드와 운명의 사랑 ... https://www.vigloo.com/ko/video/15000171?episode=1
# [182/197] 뱀파이어와의 첫사랑: 죽음의 키스 ... https://www.vigloo.com/ko/video/15000321?episode=1
# [183/197] 애니멀 리벤지~잃어버린 인연~ ... https://www.vigloo.com/ko/video/15000178?episode=1
# [184/197] 홈리스 재벌 후계자의 복수 ... https://www.vigloo.com/ko/video/15000231?episode=1
# [185/197] 두 CEO의 사랑 전쟁 ... https://www.vigloo.com/ko/video/15000326?episode=1
# [186/197] 타임슬립 로맨스: 내가 사랑한 마피아 ... https://www.vigloo.com/ko/video/15000268?episode=1
# [187/197] 거짓으로 얽힌 억만장자와의 로맨스 ... https://www.vigloo.com/ko/video/15000175?episode=1
# [188/197] 사랑의 기억은 진짜인가요? ... https://www.vigloo.com/ko/video/15000139?episode=1
# [189/197] 계약결혼으로 대표님 구하기 ... https://www.vigloo.com/ko/video/15000498?episode=1
# [190/197] 최악의 첫데이트 ... https://www.vigloo.com/ko/video/15000281?episode=1
# [191/197] 마지막 웨딩 드레스 ... https://www.vigloo.com/ko/video/15000164?episode=1
# [192/197] 잡일 부서에 발령받았습니다 ... https://www.vigloo.com/ko/video/15000177?episode=1
# [193/197] 미워할 수 없는 나의 라이벌 ... https://www.vigloo.com/ko/video/15000167?episode=1
# [194/197] 그녀를 사랑한 대가 ... https://www.vigloo.com/ko/video/15000152?episode=1
# [195/197] 큐의 단죄 ... https://www.vigloo.com/ko/video/15000163?episode=1
# [196/197] 일주일간의 동거 ... https://www.vigloo.com/ko/video/15000499?episode=1
# [197/197] 미코노스에서 생긴 일 ... https://www.vigloo.com/ko/video/15000347?episode=1
#
# ==================================================
# 수집 완료
# 총 저장 작품 수: 197개
# 저장 파일: vigloo_all_works.csv / vigloo_all_works.xlsx
# ==================================================
#    순번            제목   태그/설명 국가                  장르  \
# 0   1  천재 아기의 인생 역전     참교육        환생· · 반전· · 사이다
# 1   2  수상한 남편의 이중생활    로맨틱한        로맨스· · 재벌· · 반전
# 2   3    닿을 수 있는 그녀   초고속결혼       로맨스· · 재벌· · 사이다
# 3   4          모쏠지옥     고자극     로맨스· · 리얼리티· · 드라마
# 4   5   비서할래 와이프할래?  선결혼후연애             로맨스· · 코미디
#
#                                                  줄거리 총회차  \
# 0  친부와 새엄마 때문에 억울한 누명을 쓰고 교도소에서 숨진 도혁. 눈을 떠보니 201...  76
# 1  재벌가 후계자 자리를 박차고 나와 택시기사, 정육점, 택배기사로 ‘쓰리 잡’을 뛰며...  72
# 2  강씨 가문의 양녀 강유진은 가족의 지시로 향한 호텔에서 여자 알러지가 있는 성원그룹...  81
# 3  친구에게 속아 연애서바이벌 <핫연애존>에 입주한 솔지, 쉴 틈 없이 이어지는 고자극...  53
# 4  할머니 수술비가 필요했던 박하은은 1년간 결혼 신분을 빌려주는 계약 결혼을 하기로 ...  80
#
#                                                  URL
# 0  https://www.vigloo.com/ko/video/15001849?episo...
# 1  https://www.vigloo.com/ko/video/15001753?episo...
# 2  https://www.vigloo.com/ko/video/15001453?episo...
# 3  https://www.vigloo.com/ko/video/15001786?episo...
# 4  https://www.vigloo.com/ko/video/15001355?episo...

# %%
import pandas as pd

df = pd.read_csv("vigloo_all_works.csv")

# 줄거리, 장르 없는 거 제거
df = df.dropna(subset=["장르", "줄거리"])

df
# Out:
#       순번               제목   태그/설명  국가                  장르  \
# 0      1     천재 아기의 인생 역전     참교육 NaN     환생· · 반전· · 사이다
# 1      2     수상한 남편의 이중생활    로맨틱한 NaN     로맨스· · 재벌· · 반전
# 2      3       닿을 수 있는 그녀   초고속결혼 NaN    로맨스· · 재벌· · 사이다
# 3      4             모쏠지옥     고자극 NaN  로맨스· · 리얼리티· · 드라마
# 4      5      비서할래 와이프할래?  선결혼후연애 NaN          로맨스· · 코미디
# ..   ...              ...     ...  ..                 ...
# 192  193  미워할 수 없는 나의 라이벌    언더커버 NaN     로맨스· · 혐관· · 정치
# 193  194       그녀를 사랑한 대가      복수 NaN    로맨스· · 배신· · 사이다
# 194  195            큐의 단죄    서스펜스 NaN   스릴러· · 호러· · 삼각관계
# 195  196         일주일간의 동거    로맨틱한 NaN   혐관· · 삼각관계· · 로맨스
# 196  197      미코노스에서 생긴 일      재벌 NaN    재벌· · 언더커버· · 운명
#
#                                                    줄거리   총회차  \
# 0    친부와 새엄마 때문에 억울한 누명을 쓰고 교도소에서 숨진 도혁. 눈을 떠보니 201...  76.0
# 1    재벌가 후계자 자리를 박차고 나와 택시기사, 정육점, 택배기사로 ‘쓰리 잡’을 뛰며...  72.0
# 2    강씨 가문의 양녀 강유진은 가족의 지시로 향한 호텔에서 여자 알러지가 있는 성원그룹...  81.0
# 3    친구에게 속아 연애서바이벌 <핫연애존>에 입주한 솔지, 쉴 틈 없이 이어지는 고자극...  53.0
# 4    할머니 수술비가 필요했던 박하은은 1년간 결혼 신분을 빌려주는 계약 결혼을 하기로 ...  80.0
# ..                                                 ...   ...
# 192  대담한 정치 전략가 클로이 하퍼는 선거 유세 현장에서 라이벌 트래비스 콜과 충돌한다...  49.0
# 193  소설가 앨릭스 크로는 무자비한 헥터 크루즈와의 해로운 결혼 생활에 갇힌 아름다운 여...  48.0
# 194  행복한 소마 일가 앞에 갑자기 나타난 수수께끼의 인물 큐타로. 소마 일가의 일상에 ...  49.0
# 195  극과 극인 두 사람이 일주일간 같은 집에서 살게 된다. 엉망진창이었던 그들의 생활은...  49.0
# 196  미코노스섬에서 미국인 사진작가 케이트는 그리스 해운 재벌가의 상속자라는 비밀을 간직...  49.0
#
#                                                    URL
# 0    https://www.vigloo.com/ko/video/15001849?episo...
# 1    https://www.vigloo.com/ko/video/15001753?episo...
# 2    https://www.vigloo.com/ko/video/15001453?episo...
# 3    https://www.vigloo.com/ko/video/15001786?episo...
# 4    https://www.vigloo.com/ko/video/15001355?episo...
# ..                                                 ...
# 192  https://www.vigloo.com/ko/video/15000167?episo...
# 193  https://www.vigloo.com/ko/video/15000152?episo...
# 194  https://www.vigloo.com/ko/video/15000163?episo...
# 195  https://www.vigloo.com/ko/video/15000499?episo...
# 196  https://www.vigloo.com/ko/video/15000347?episo...
#
# [196 rows x 8 columns]

# %%
# 장르 분리
df["장르"] = df["장르"].str.replace(" ", "")
df["장르리스트"] = df["장르"].str.split("·")

# explode로 행 펼치기
genre_df = df.explode("장르리스트")

# 빈값 제거
genre_df = genre_df[genre_df["장르리스트"] != ""]

# 장르별 개수
genre_count = genre_df["장르리스트"].value_counts()

print(genre_count)
# Out:
# 장르리스트
# 로맨스       137
# 재벌         43
# 사이다        34
# 드라마        29
# 판타지        28
# 반전         26
# 코미디        23
# 운명         23
# 삼각관계       20
# 찐사랑        18
# 배신         18
# 치정         16
# 혐관         14
# 스릴러        13
# 재회         10
# 다정남         9
# 환생          9
# 로코          7
# 금지된사랑       7
# 언더커버        7
# 리얼리티        6
# 미스터리        6
# 하이틴         5
# 시대극/사극      4
# 초고속결혼       3
# 로판          3
# 늑대인간        3
# 뱀파이어        3
# 호러          3
# 이혼          3
# SF          3
# 고자극         3
# 연상연하        3
# 걸크러쉬        3
# 순애          3
# CEO         2
# 액션          2
# 계약연애        2
# 애니메이션       1
# 아이돌         1
# 친구>연인       1
# 신분상승        1
# 정치          1
# Name: count, dtype: int64

# %%
import plotly.express as px

top10 = genre_count.head(10)

fig = px.bar(
    x=top10.index,
    y=top10.values,
    labels={"x": "장르", "y": "콘텐츠 수"},
    title="장르별 콘텐츠 분포 TOP10"
)

fig.show()

# %%
import pandas as pd

df = pd.read_csv("vigloo_all_works.csv")

# 숫자로 변환
df["총회차"] = pd.to_numeric(df["총회차"], errors="coerce")

# 전체 평균
avg_episode = df["총회차"].mean()

print(f"전체 평균 회차: {avg_episode:.2f}")
# Out:
# 전체 평균 회차: 52.43

# %%
# 장르 정리
df["장르"] = df["장르"].str.replace(" ", "")
df["장르리스트"] = df["장르"].str.split("·")

# 펼치기
genre_df = df.explode("장르리스트")

# 빈값 제거
genre_df = genre_df[genre_df["장르리스트"] != ""]

# %%
genre_avg = (
    genre_df
    .groupby("장르리스트")["총회차"]
    .mean()
    .sort_values(ascending=False)
)

print(genre_avg.head(10))
# Out:
# 장르리스트
# 사이다       59.029412
# 시대극/사극    58.750000
# 걸크러쉬      58.333333
# 친구>연인     58.000000
# 환생        57.777778
# 반전        57.269231
# 로판        56.333333
# 혐관        55.928571
# 재벌        55.558140
# 언더커버      54.142857
# Name: 총회차, dtype: float64

# %%
import plotly.express as px

# 1. 장르 개수 TOP10
top_genres = genre_count.head(10).index

# 2. 그 장르들의 평균 회차
top10_avg = genre_avg.loc[top_genres]

# 3. 시각화
fig = px.bar(
    x=top10_avg.index,
    y=top10_avg.values,
    labels={"x": "장르", "y": "평균 회차"},
    title="TOP10 장르별 평균 회차"
)

fig.show()

# %%
# 공백 제거 + 분리
df["태그/설명"] = df["태그/설명"].str.replace(" ", "")
df["태그리스트"] = df["태그/설명"].str.split("·")

# explode
tag_df = df.explode("태그리스트")

# 빈값 제거
tag_df = tag_df[tag_df["태그리스트"] != ""]

tag_count = tag_df["태그리스트"].value_counts()

top10_tags = tag_count.head(10)

print(top10_tags)
# Out:
# 태그리스트
# 언더커버     16
# 복수       14
# 로코       13
# 재벌       11
# 비밀신분      9
# 나이차이      6
# 청춘물       6
# 계약결혼      6
# 금지된사랑     5
# 고자극       5
# Name: count, dtype: int64

# %%
import plotly.express as px

fig = px.bar(
    x=top10_tags.index,
    y=top10_tags.values,
    labels={"x": "태그", "y": "콘텐츠 수"},
    title="태그/설명 TOP10"
)

fig.show()
